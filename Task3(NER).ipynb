# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn_crfsuite import CRF
from sklearn_crfsuite.metrics import flat_f1_score
from sklearn_crfsuite.metrics import flat_classification_report
import nltk
from nltk.tag import pos_tag
import string
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/pavel/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ### Загрузка данных

# %%
data = None
with open('data1.txt', 'r', encoding='utf8') as file:
    data = file.readlines()

# %%
del data[0]

# %%
def create_dict(data, drop_punct = False):    
    '''Returns dict with words and tags for furher creating DataFrame
    
    # Arguments
        data: list of strings (sentences)
        drop_punct: bool (drop punctuation or not)
        
    # Returns
        dict
    '''
    words = [] 
    tags = []
    sentences = []     # Добавим словам метки принадлежности к предложениям 
    num = 0
    for i, sent in enumerate(data):
        if sent != '\n':      # в исходном датасете предложения разделены пустой строкой
            s = sent.split()
            if drop_punct and all(x in string.punctuation for x in s[0]):  # проверка, 
                continue                                        # состоит ли строка полностью из знаков пунктуации
            words.append(s[0])
            tags.append(s[1])
            sentences.append(f'Sentence: {num}')
        else:        
            num += 1
            
    return {'Sentence #': sentences, 'Word':words, 'Tag':tags}

# %%
# Создаём Датафрейм для дальнейшего анализа данных
df = pd.DataFrame(create_dict(data))
df.head()
# Out:
#     Sentence #    Word Tag
# 0  Sentence: 0     Man   O
# 1  Sentence: 0       i   O
# 2  Sentence: 0    hate   O
# 3  Sentence: 0    when   O
# 4  Sentence: 0  people   O

# %% [markdown]
# ### Изучение данных

# %%
df.describe()
# Out:
#             Sentence #    Word     Tag
# count           124629  124629  124629
# unique            7243   28819      21
# top     Sentence: 4654       .       O
# freq                41    3495  115084

# %% [markdown]
# В нашем датасете 7423 предложения с 124629 токенами, самым частотным из которых является '.' - точка.

# %% [markdown]
# ##### Распределение тэгов

# %%
df.groupby('Tag').count()
# Out:
#                Sentence #    Word
# Tag
# B-company             831     831
# B-facility            395     395
# B-geo-loc            1274    1274
# B-movie                83      83
# B-musicartist         287     287
# B-other               941     941
# B-person             1102    1102
# B-product             380     380
# B-sportsteam          268     268
# B-tvshow               69      69
# I-company             311     311
# I-facility            510     510
# I-geo-loc             310     310
# I-movie               109     109
# I-musicartist         236     236
# I-other               973     973
# I-person              610     610
# I-product             701     701
# I-sportsteam           84      84
# I-tvshow               71      71
# O                  115084  115084

# %% [markdown]
# ##### Распределение тэгов (круговая диаграмма)

# %%
df.groupby('Tag').Word.count().plot.pie()

# %% [markdown]
# Тэг принадлежности к неименованной сущности ожидаемо гораздо более распространён

# %% [markdown]
# ##### Распределение тэгов именованных сущностей

# %%
df[df.Tag != 'O'].groupby('Tag').Word.count().plot.bar()

# %% [markdown]
# ##### Пунктуация

# %%
df[(df.Word == '.') & (df.Tag != 'O')].head() # точки, имеющие тэг именованной сущности (первые 5)
# Out:
#           Sentence # Word           Tag
# 211     Sentence: 12    .      I-person
# 1243    Sentence: 72    .    I-facility
# 4854   Sentence: 287    .  I-sportsteam
# 9433   Sentence: 555    .     I-company
# 11352  Sentence: 656    .      I-person

# %% [markdown]
# Несмотря на то, что некоторые знаки пунктуации имеют тэг принадлежности к именованной сущности, на деле они ими не являются. Тем не менее, возможно, они несут некоторую дополнительную информацию для определения настоящих именованных сущностей.
# Попробуем обучить модель как на данных со знаками, так и без.

# %%
# Создаём Датафрейм без знаков препинания (DataFrame Without Punctiation)
df_wp = pd.DataFrame(create_dict(data, drop_punct=True))
df_wp.head()
# Out:
#     Sentence #    Word Tag
# 0  Sentence: 0     Man   O
# 1  Sentence: 0       i   O
# 2  Sentence: 0    hate   O
# 3  Sentence: 0    when   O
# 4  Sentence: 0  people   O

# %%
df_wp.describe()
# Out:
#             Sentence #    Word     Tag
# count           108395  108395  108395
# unique            7243   28626      21
# top     Sentence: 2417     the       O
# freq                36    2059   99000

# %% [markdown]
# ### POS-тэги
# Для задачи выделения именованных сущностей хорошим признаком является частеречная разметка. Её можно выполнить посредством библиотеки NLTK.

# %%
def create_pos_tags(data):
    '''Returns list of POS-tags
    
    # Arguments
        data: pandas.DataFrame, it must have columns 'Sentence #' and 'Word'
        
    # Returns
        list of strings
    '''
    agg = lambda s: [w for w in s['Word'].values.tolist()] # составляем предложения - список слов для каждого
    grouped = data.groupby("Sentence #").apply(agg)
    sentences = [s for s in grouped]    
    pos_tags = [nltk.pos_tag(sent) for sent in sentences]
    pos_tags = [tag[1] for pair in pos_tags for tag in pair]
   
    return pos_tags

# %%
pos_tags = create_pos_tags(df)
print(f'POS-тэги для первых пяти слов:\n{pos_tags[:5]}')
# Out:
# POS-тэги для первых пяти слов:
# ['NN', 'NN', 'VBP', 'WRB', 'NNS']

# %%
df.insert(2, 'POS', pos_tags)
df.head()
# Out:
#     Sentence #    Word  POS Tag
# 0  Sentence: 0     Man   NN   O
# 1  Sentence: 0       i   NN   O
# 2  Sentence: 0    hate  VBP   O
# 3  Sentence: 0    when  WRB   O
# 4  Sentence: 0  people  NNS   O

# %% [markdown]
# ### Создание признаков
# Возьмем в качестве признаков часть тех, что описаны в данной статье https://arxiv.org/pdf/1709.04820.pdf, как "handcraft features".
# Среди них:
#  - длина слова
#  - POS-тэг
#  - шаблоны капитализации
#  - суффиксы и префиксы слов
#  - метки первого и последнего слов в предложении
#  - и другие
#
# Кроме того, в списке признаков каждого слова будут присутствовать признаки его слов-соседей.
#
# В вышеуказанной статье также присутствуют в качестве признаков эмбеддинги слов и предложений, но за неимением достаточных вычислительных мощностей и оперативной памяти, чтобы использовать предобученные векторы, в данной работе они не присутствуют.
#
# Код частично взят из статьи https://www.depends-on-the-definition.com/named-entity-recognition-conditional-random-fields-python/

# %%
# Класс для получения предложений, представленных в виде списка кортежей со словом, pos-тэгом и тэгом в каждом
class sentence(object):
    def __init__(self, df):
        self.n_sent = 1
        self.df = df
        self.empty = False
        agg = lambda s : [(w, p, t) for w, p, t in zip(s['Word'].values.tolist(),
                                                       s['POS'].values.tolist(),
                                                       s['Tag'].values.tolist())]
        self.grouped = self.df.groupby("Sentence #").apply(agg)
        self.sentences = [s for s in self.grouped]

# %%
# для датафрейма с пуктуацией
getter = sentence(df)
sentences = getter.sentences
print(f'Каждое предложение имеет вид:\n{sentences[0]}')
# Out:
# Каждое предложение имеет вид:
# [('Man', 'NN', 'O'), ('i', 'NN', 'O'), ('hate', 'VBP', 'O'), ('when', 'WRB', 'O'), ('people', 'NNS', 'O'), ('carry', 'VBP', 'O'), ('ragedy', 'JJ', 'O'), ('luggage', 'NN', 'O'), ('..', 'NNP', 'O'), ('ima', 'NN', 'O'), ('just', 'RB', 'O'), ('rip', 'VB', 'O'), ('it', 'PRP', 'O'), ('up', 'RP', 'O'), ('more', 'RBR', 'O'), ('with', 'IN', 'O'), ('the', 'DT', 'O'), ('belt', 'NN', 'O'), ('loader', 'NN', 'O'), ('#itaintmines', 'NNS', 'O')]

# %%
# функция генерация признаков
def word2features(sent, i):
    ''' Returns dict of features
    
    # Arguments
        sent: tuple(word, pos, tag)
        i: int, index of tuple in list
        
    # Returns
        dict
    '''
    word = sent[i][0]
    postag = sent[i][1]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[:3]': word[:3],
        'word[:2]': word[:2],             # префикс
        'word[-3:]': word[-3:],           # суффикс
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(), # капитализация
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True    # Первое слово в предложении

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True  # Последнее слово в предложении

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

# %%
# для датафрейма с пунктуацией 
X = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# В качестве алгоритма классификации были опробованы Perceptron, SGDClassifier, CRF (метод условных случайных полей).
# Последний показал наилучшие результаты.
# Использование нейронных сетей и языковых моделей, как, например, здесь: https://www.depends-on-the-definition.com/named-entity-recognition-with-bert/ - невозможно ввиду ограниченных вычислительных ресурсов (а также малой обучающей выборки).
# Ниже приведен код для обучения CRF-классификатора и оценки его предсказаний.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=43)

# %%
crf = CRF(algorithm = 'lbfgs',
         c1 = 0.1,
         c2 = 0.1,
         max_iterations = 100,
         all_possible_transitions = False)
crf.fit(X_train, y_train)
# Out:
# CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=False,
#     averaging=None, c=None, c1=0.1, c2=0.1, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %%
print(flat_classification_report(y_pred=crf.predict(X_test), y_true=y_test))
# Out:
#                precision    recall  f1-score   support
#
#     B-company       0.79      0.53      0.63       156
#    B-facility       0.78      0.53      0.63        87
#     B-geo-loc       0.83      0.53      0.64       258
#       B-movie       0.80      0.18      0.30        22
# B-musicartist       0.40      0.15      0.22        54
#       B-other       0.69      0.40      0.50       179
#      B-person       0.68      0.42      0.52       225
#     B-product       0.52      0.20      0.29        71
#  B-sportsteam       0.50      0.22      0.31        50
#      B-tvshow       1.00      0.06      0.11        17
#     I-company       0.60      0.48      0.53        73
#    I-facility       0.80      0.62      0.70       117
#     I-geo-loc       0.85      0.42      0.56        69
#       I-movie       1.00      0.24      0.39        29
# I-musicartist       0.27      0.06      0.10        62
#       I-other       0.56      0.43      0.49       169
#      I-person       0.63      0.52      0.57       124
#     I-product       0.31      0.29      0.30       139
#  I-sportsteam       0.50      0.20      0.29        15
#      I-tvshow       0.00      0.00      0.00        23
#             O       0.96      0.99      0.98     23166
#
#      accuracy                           0.95     25105
#     macro avg       0.64      0.36      0.43     25105
#  weighted avg       0.94      0.95      0.94     25105

# %% [markdown]
# Из-за присутствия дисбаланса в классах (представителей класса 'O' гораздо больше остальных) результаты получаются завышенными.
#
#
# Исключим данный тэг из нашего набора классов и посмотрим на более правдивый отчет.

# %%
new_classes = df.Tag.unique().tolist()
new_classes.pop(0)
new_classes
# Out:
# ['B-sportsteam',
#  'I-sportsteam',
#  'B-facility',
#  'I-facility',
#  'B-company',
#  'B-geo-loc',
#  'B-other',
#  'I-other',
#  'B-person',
#  'I-person',
#  'B-movie',
#  'I-movie',
#  'B-product',
#  'I-product',
#  'I-geo-loc',
#  'B-musicartist',
#  'I-musicartist',
#  'B-tvshow',
#  'I-company',
#  'I-tvshow']

# %%
print(flat_classification_report(y_pred=crf.predict(X_test), y_true=y_test, labels=new_classes))
# Out:
#                precision    recall  f1-score   support
#
#  B-sportsteam       0.50      0.22      0.31        50
#  I-sportsteam       0.50      0.20      0.29        15
#    B-facility       0.78      0.53      0.63        87
#    I-facility       0.80      0.62      0.70       117
#     B-company       0.79      0.53      0.63       156
#     B-geo-loc       0.83      0.53      0.64       258
#       B-other       0.69      0.40      0.50       179
#       I-other       0.56      0.43      0.49       169
#      B-person       0.68      0.42      0.52       225
#      I-person       0.63      0.52      0.57       124
#       B-movie       0.80      0.18      0.30        22
#       I-movie       1.00      0.24      0.39        29
#     B-product       0.52      0.20      0.29        71
#     I-product       0.31      0.29      0.30       139
#     I-geo-loc       0.85      0.42      0.56        69
# B-musicartist       0.40      0.15      0.22        54
# I-musicartist       0.27      0.06      0.10        62
#      B-tvshow       1.00      0.06      0.11        17
#     I-company       0.60      0.48      0.53        73
#      I-tvshow       0.00      0.00      0.00        23
#
#     micro avg       0.65      0.41      0.50      1939
#     macro avg       0.63      0.32      0.40      1939
#  weighted avg       0.65      0.41      0.49      1939

# %% [markdown]
# Стоит обратить внимание на класс I-tvshow, оценки качества классификации которого равны нулю. Это самый малочисленный класс, поэтому либо классификатору не хватило данных, чтобы обучиться его классифицировать, либо объекты с данным тэгом вовсе не попали в обучающую выборку.

# %% [markdown]
# #### Датафрейм без пунктуации
# Проверим, как исключение пунктуации повлияет на работу алгоритма.

# %%
# df_wp.insert(2, 'POS', create_pos_tags(df_wp)) # для данных без пунктуации
getter = sentence(df_wp)
sentences = getter.sentences

X = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=43) 

crf = CRF(algorithm = 'lbfgs',
         c1 = 0.1,
         c2 = 0.1,
         max_iterations = 100,
         all_possible_transitions = False)

crf.fit(X_train, y_train)

print(flat_classification_report(y_pred=crf.predict(X_test), y_true=y_test, labels=new_classes))
# Out:
#                precision    recall  f1-score   support
#
#  B-sportsteam       0.47      0.18      0.26        50
#  I-sportsteam       0.29      0.14      0.19        14
#    B-facility       0.78      0.52      0.62        87
#    I-facility       0.78      0.59      0.67       116
#     B-company       0.83      0.53      0.65       156
#     B-geo-loc       0.79      0.52      0.62       258
#       B-other       0.68      0.39      0.50       179
#       I-other       0.53      0.39      0.45       162
#      B-person       0.70      0.42      0.53       225
#      I-person       0.68      0.56      0.61       120
#       B-movie       1.00      0.09      0.17        22
#       I-movie       1.00      0.21      0.34        29
#     B-product       0.73      0.23      0.34        71
#     I-product       0.46      0.23      0.31       128
#     I-geo-loc       0.68      0.42      0.51        65
# B-musicartist       0.73      0.15      0.25        54
# I-musicartist       0.67      0.07      0.13        55
#      B-tvshow       1.00      0.06      0.11        17
#     I-company       0.70      0.39      0.50        71
#      I-tvshow       0.00      0.00      0.00        22
#
#     micro avg       0.70      0.40      0.51      1901
#     macro avg       0.67      0.30      0.39      1901
#  weighted avg       0.69      0.40      0.49      1901

# %% [markdown]
# Для классификации некоторых классов (например, B-person и I-person) результаты для данного датасета получились выше, в то время как для других классов - ниже. В целом - что на датасете без пунктуацией, что с ней - результаты классификации оказались приблизительно равными.

# %% [markdown]
# Ниже можно ознакомиться с результатами работы алгоритма

# %%
for k, i, j in zip(X_test, crf.predict(X_test), y_test):
    #print(i, end='\n\n')
    for w, a, b in zip(k, i, j):
        print(f'{w["word.lower()"]}: Predict: {a}, True: {b}')
# Out:
# after: Predict: O, True: O
# the: Predict: O, True: O
# san: Predict: B-geo-loc, True: B-geo-loc
# bernardino: Predict: I-geo-loc, True: I-geo-loc
# shooting: Predict: O, True: O
# three: Predict: O, True: O
# approaches: Predict: O, True: O
# to: Predict: O, True: O
# gun: Predict: O, True: O
# violence: Predict: O, True: O
# http://www.newyorker.com/news/news-desk/after-the-san-bernardino-shooting-three-approaches-to-gun-violence: Predict: O, True: O
# …: Predict: O, True: O
# via: Predict: O, True: O
# @joshuarothman: Predict: O, True: O
# rt: Predict: O, True: O
# @cochraneeagle: Predict: O, True: O
# your: Predict: O, True: O
# #cochrane: Predict: B-sportsteam, True: B-product
# eagle: Predict: I-sportsteam, True: I-product
# front: Predict: O, True: O
# for: Predict: O, True: O
# april: Predict: O, True: O
# 23: Predict: O, True: O
# 2015: Predict: O, True: O
# http://t.co/ptnmefjhc3: Predict: O, True: O
# apple: Predict: B-product, True: B-product
# ipod: Predict: I-product, True: I-product
# touch: Predict: I-product, True: I-product
# 4th: Predict: I-product, True: I-product
# generation: Predict: I-product, True: I-product
# 16gb: Predict: I-product, True: I-product
# black: Predict: I-product, True: I-product
# full: Predict: O, True: O
# read: Predict: O, True: O
# by: Predict: O, True: O
# ebay: Predict: B-company, True: O
# http://t.co/z1ip45qadq: Predict: O, True: O
# http://t.co/9pikoldehr: Predict: O, True: O
# @maike_84: Predict: O, True: O
# flikken: Predict: O, True: B-tvshow
# is: Predict: O, True: O
# geweldig: Predict: O, True: O
# ik: Predict: O, True: O
# kan: Predict: O, True: O
# niet: Predict: O, True: O
# wachten: Predict: O, True: O
# tot: Predict: O, True: O
# de: Predict: O, True: O
# nieuwe: Predict: O, True: O
# serie: Predict: O, True: O
# in: Predict: O, True: O
# november: Predict: O, True: O
# (geloof: Predict: O, True: O
# ik: Predict: O, True: O
# dit: Predict: O, True: O
# jaar: Predict: O, True: O
# alles: Predict: O, True: O
# gezien: Predict: O, True: O
# via: Predict: O, True: O
# uitzendinggemist: Predict: O, True: O
# goodnight: Predict: O, True: O
# twitterland: Predict: O, True: O
# seee: Predict: O, True: O
# you: Predict: O, True: O
# tomorrow: Predict: O, True: O
# michael: Predict: O, True: B-person
# i: Predict: O, True: O
# love: Predict: O, True: O
# you: Predict: O, True: O
# more: Predict: O, True: O
# than: Predict: O, True: O
# my: Predict: O, True: O
# life: Predict: O, True: O
# the: Predict: O, True: O
# biggest: Predict: O, True: O
# kiss: Predict: O, True: O
# for: Predict: O, True: O
# you: Predict: O, True: O
# my: Predict: O, True: O
# love: Predict: O, True: O
# :d: Predict: O, True: O
# l: Predict: O, True: O
# o: Predict: O, True: O
# v: Predict: O, True: O
# e: Predict: O, True: O
# breaking: Predict: O, True: B-movie
# dawn: Predict: O, True: I-movie
# returns: Predict: O, True: O
# to: Predict: O, True: O
# vancouver: Predict: B-geo-loc, True: B-geo-loc
# on: Predict: O, True: O
# january: Predict: O, True: O
# 11th: Predict: O, True: O
# http://bit.ly/dbdms8: Predict: O, True: O
# snapchat: Predict: B-company, True: B-company
# 's: Predict: O, True: O
# security: Predict: O, True: O
# breach: Predict: O, True: O
# exposes: Predict: O, True: O
# broader: Predict: O, True: O
# mobile: Predict: O, True: O
# vulnerabilities: Predict: O, True: O
# http://ift.tt/19dy0ub: Predict: O, True: O
# http://ift.tt/19dy0ub: Predict: O, True: O
# rt: Predict: O, True: O
# @yourrowysodate: Predict: O, True: O
# 3: Predict: O, True: O
# june: Predict: O, True: O
# 2015: Predict: O, True: O
# leeds: Predict: O, True: B-geo-loc
# uk: Predict: B-geo-loc, True: B-geo-loc
# first: Predict: O, True: B-facility
# direct: Predict: O, True: I-facility
# arena: Predict: O, True: I-facility
# @sairsp: Predict: O, True: O
# our: Predict: O, True: O
# flight: Predict: O, True: O
# is: Predict: O, True: O
# 1: Predict: O, True: O
# of: Predict: O, True: O
# the: Predict: O, True: O
# only: Predict: O, True: O
# 5: Predict: O, True: O
# that: Predict: O, True: O
# are: Predict: O, True: O
# leaving: Predict: O, True: O
# today: Predict: O, True: O
# from: Predict: O, True: O
# venice: Predict: O, True: B-geo-loc
# feeling: Predict: O, True: O
# very: Predict: O, True: O
# very: Predict: O, True: O
# #lucky: Predict: O, True: O
# hope: Predict: O, True: O
# to: Predict: O, True: O
# make: Predict: O, True: O
# it: Predict: O, True: O
# back: Predict: O, True: O
# on: Predict: O, True: O
# sunday: Predict: O, True: O
# @easyjet: Predict: O, True: O
# rt: Predict: O, True: O
# @wsj: Predict: O, True: O
# breaking: Predict: O, True: O
# mario: Predict: B-person, True: B-person
# draghi: Predict: I-person, True: I-person
# says: Predict: O, True: O
# ecb: Predict: O, True: B-company
# to: Predict: O, True: O
# start: Predict: O, True: O
# purchasing: Predict: O, True: O
# government: Predict: O, True: O
# bonds: Predict: O, True: O
# march: Predict: O, True: O
# 9: Predict: O, True: O
# http://t.co/tbe02eyvhm: Predict: O, True: O
# @regyates: Predict: O, True: O
# mate: Predict: O, True: O
# you're: Predict: O, True: O
# a: Predict: O, True: O
# legend: Predict: O, True: O
# it: Predict: O, True: O
# 's: Predict: O, True: O
# scary: Predict: O, True: O
# how: Predict: O, True: O
# people: Predict: O, True: O
# in: Predict: O, True: O
# the: Predict: O, True: O
# 21st: Predict: O, True: O
# just: Predict: O, True: O
# a: Predict: O, True: O
# plane: Predict: O, True: O
# ride: Predict: O, True: O
# away: Predict: O, True: O
# have: Predict: O, True: O
# these: Predict: O, True: O
# views: Predict: O, True: O
# @jemelehill: Predict: O, True: O
# i: Predict: O, True: O
# hit: Predict: O, True: O
# that: Predict: O, True: O
# jl: Predict: O, True: B-person
# joint: Predict: O, True: O
# when: Predict: O, True: O
# it: Predict: O, True: O
# came: Predict: O, True: O
# out: Predict: O, True: O
# he: Predict: O, True: O
# does: Predict: O, True: O
# teddy: Predict: O, True: B-person
# p: Predict: O, True: I-person
# proud: Predict: O, True: O
# on: Predict: O, True: O
# wake: Predict: O, True: O
# up: Predict: O, True: O
# in: Predict: O, True: O
# pawnee: Predict: B-geo-loc, True: B-geo-loc
# lsa: Predict: O, True: B-sportsteam
# 5-4: Predict: O, True: O
# vs: Predict: O, True: O
# pawnee: Predict: B-sportsteam, True: B-sportsteam
# 8-1: Predict: O, True: O
# 1st: Predict: O, True: O
# round: Predict: O, True: O
# playoff: Predict: O, True: O
# match: Predict: O, True: O
# less: Predict: O, True: O
# than: Predict: O, True: O
# 20: Predict: O, True: O
# min: Predict: O, True: O
# away: Predict: O, True: O
# rt: Predict: O, True: O
# @macmiller: Predict: O, True: O
# york: Predict: O, True: B-geo-loc
# pa: Predict: O, True: B-geo-loc
# i'll: Predict: O, True: O
# be: Predict: O, True: O
# there: Predict: O, True: O
# saturday: Predict: O, True: O
# snapchat: Predict: B-company, True: B-company
# responds: Predict: O, True: O
# to: Predict: O, True: O
# new: Predict: B-other, True: B-other
# year: Predict: I-other, True: I-other
# 's: Predict: I-other, True: I-other
# eve: Predict: I-other, True: I-other
# security: Predict: O, True: O
# breach: Predict: O, True: O
# http://bit.ly/19nawnt: Predict: O, True: O
# #news: Predict: O, True: O
# rt: Predict: O, True: O
# @susana_hazz: Predict: O, True: O
# when: Predict: O, True: O
# you: Predict: O, True: O
# realize: Predict: O, True: O
# it's: Predict: O, True: O
# the: Predict: O, True: O
# 2nd: Predict: O, True: O
# day: Predict: O, True: O
# of: Predict: O, True: O
# 2015: Predict: O, True: O
# and: Predict: O, True: O
# the: Predict: O, True: O
# fandom: Predict: O, True: O
# is: Predict: O, True: O
# slaying: Predict: O, True: O
# #congratsonthebabyniall: Predict: O, True: O
# http://t.co/ucqbiysypu: Predict: O, True: O
# omg: Predict: O, True: O
# i'm: Predict: O, True: O
# sooooo: Predict: O, True: O
# ready: Predict: O, True: O
# for: Predict: O, True: O
# tonight: Predict: O, True: O
# &lt;: Predict: O, True: O
# 3: Predict: O, True: O
# wow: Predict: O, True: O
# a: Predict: O, True: O
# school: Predict: O, True: O
# shooting: Predict: O, True: O
# in: Predict: O, True: O
# marysville: Predict: B-geo-loc, True: B-geo-loc
# washington: Predict: B-geo-loc, True: B-geo-loc
# that: Predict: O, True: O
# 's: Predict: O, True: O
# too: Predict: O, True: O
# close: Predict: O, True: O
# i: Predict: O, True: O
# don't: Predict: O, True: O
# feel: Predict: O, True: O
# safe: Predict: O, True: O
# at: Predict: O, True: O
# school: Predict: O, True: O
# anymore: Predict: O, True: O
# that: Predict: O, True: O
# 's: Predict: O, True: O
# sad: Predict: O, True: O
# “@ap: Predict: O, True: O
# breaking: Predict: O, True: O
# nopd: Predict: B-other, True: B-other
# says: Predict: O, True: O
# 12: Predict: O, True: O
# hurt: Predict: O, True: O
# at: Predict: O, True: O
# new: Predict: B-geo-loc, True: B-geo-loc
# orleans: Predict: I-geo-loc, True: I-geo-loc
# mother: Predict: B-other, True: B-other
# 's: Predict: I-other, True: I-other
# day: Predict: I-other, True: I-other
# second-line: Predict: O, True: O
# parade: Predict: O, True: O
# shooting: Predict: O, True: O
# http://apne.ws/13rgtwe: Predict: O, True: O
# -rjj”: Predict: O, True: O
# more: Predict: O, True: O
# guns: Predict: O, True: O
# going: Predict: O, True: O
# to: Predict: O, True: O
# watch: Predict: O, True: O
# american: Predict: O, True: B-movie
# sniper: Predict: O, True: I-movie
# tonight: Predict: O, True: O
# for: Predict: O, True: O
# the: Predict: O, True: O
# 32nd: Predict: O, True: O
# time: Predict: O, True: O
# #chattanoogashooting: Predict: O, True: O
# ooo: Predict: O, True: O
# @claireymarsh: Predict: O, True: O
# where: Predict: O, True: O
# are: Predict: O, True: O
# you: Predict: O, True: O
# when: Predict: O, True: O
# i: Predict: O, True: O
# need: Predict: O, True: O
# you: Predict: O, True: O
# my: Predict: O, True: O
# birthday: Predict: O, True: O
# is: Predict: O, True: O
# on: Predict: O, True: O
# 23: Predict: O, True: O
# of: Predict: O, True: O
# march: Predict: O, True: O
# i: Predict: O, True: O
# want: Predict: O, True: O
# u: Predict: O, True: O
# to: Predict: O, True: O
# follow: Predict: O, True: O
# me: Predict: O, True: O
# your: Predict: O, True: O
# follow: Predict: O, True: O
# will: Predict: O, True: O
# be: Predict: O, True: O
# the: Predict: O, True: O
# best: Predict: O, True: O
# gift: Predict: O, True: O
# i`m: Predict: O, True: O
# russian: Predict: O, True: O
# belieber: Predict: O, True: O
# @justinbieber: Predict: O, True: O
# ~967~: Predict: O, True: O
# how: Predict: O, True: O
# many: Predict: O, True: O
# times: Predict: O, True: O
# can: Predict: O, True: O
# you: Predict: O, True: O
# possibly: Predict: O, True: O
# make: Predict: O, True: O
# an: Predict: O, True: O
# excuse: Predict: O, True: O
# to: Predict: O, True: O
# play: Predict: O, True: O
# a: Predict: O, True: O
# goddamn: Predict: O, True: O
# banjo: Predict: O, True: O
# in: Predict: O, True: O
# an: Predict: O, True: O
# hour-long: Predict: O, True: O
# show: Predict: O, True: O
# a: Predict: O, True: O
# show: Predict: O, True: O
# that: Predict: O, True: O
# has: Predict: O, True: O
# nothing: Predict: O, True: O
# to: Predict: O, True: O
# do: Predict: O, True: O
# with: Predict: O, True: O
# banjos: Predict: O, True: O
# have: Predict: O, True: O
# yourselves: Predict: O, True: O
# freaky: Predict: O, True: O
# funky: Predict: O, True: O
# holidays: Predict: O, True: O
# when: Predict: O, True: O
# franny: Predict: B-person, True: B-product
# stein: Predict: I-person, True: I-product
# hits: Predict: O, True: O
# the: Predict: O, True: O
# glitter: Predict: O, True: O
# game: Predict: O, True: O
# this: Predict: O, True: O
# february: Predict: O, True: O
# https://t.co/6tomfqaara: Predict: O, True: O
# https://t.co/harntjmsds: Predict: O, True: O
# i: Predict: O, True: O
# saw: Predict: O, True: O
# @tattedup_flyty: Predict: O, True: O
# one: Predict: O, True: O
# day: Predict: O, True: O
# walkin: Predict: O, True: O
# 2: Predict: O, True: O
# the: Predict: O, True: O
# store: Predict: O, True: O
# and: Predict: O, True: O
# this: Predict: O, True: O
# foo: Predict: O, True: O
# tripped: Predict: O, True: O
# and: Predict: O, True: O
# tried: Predict: O, True: O
# 2: Predict: O, True: O
# play: Predict: O, True: O
# it: Predict: O, True: O
# off: Predict: O, True: O
# lol: Predict: O, True: O
# rt: Predict: O, True: O
# @agiwaldw: Predict: O, True: O
# toltec: Predict: O, True: O
# warriors: Predict: O, True: O
# 10th-12th: Predict: O, True: O
# century: Predict: O, True: O
# ce: Predict: O, True: O
# tollan: Predict: O, True: B-geo-loc
# tula: Predict: O, True: O
# #mexico: Predict: O, True: B-geo-loc
# #archaeology: Predict: O, True: O
# by: Predict: O, True: O
# luidger: Predict: O, True: B-person
# http://t.co/hd7u46zrvb: Predict: O, True: O
# pre: Predict: O, True: O
# order: Predict: O, True: O
# jaket: Predict: B-product, True: B-product
# korea: Predict: I-product, True: I-product
# chelsea: Predict: I-product, True: I-product
# ride: Predict: I-product, True: I-product
# sd: Predict: O, True: I-product
# 7: Predict: O, True: O
# jan: Predict: O, True: O
# 185k: Predict: O, True: O
# belum: Predict: O, True: O
# ongkir: Predict: O, True: O
# @rio_intan: Predict: O, True: O
# sms/wa: Predict: O, True: O
# 081235994171: Predict: O, True: O
# pin: Predict: O, True: O
# 512a3491: Predict: O, True: O
# http://t.co/qvn7jhp0ii: Predict: O, True: O
# rt: Predict: O, True: O
# @gelatiscoop: Predict: O, True: O
# appreciate: Predict: O, True: O
# your: Predict: O, True: O
# recent: Predict: O, True: O
# retweets: Predict: O, True: O
# @cargo_pal: Predict: O, True: O
# @michael_0000: Predict: O, True: O
# @chunksie101: Predict: O, True: O
# have: Predict: O, True: O
# a: Predict: O, True: O
# great: Predict: O, True: O
# sunday: Predict: O, True: O
# bagan: Predict: O, True: O
# #copadelrey: Predict: O, True: O
# 2014-15: Predict: O, True: O
# 16besar: Predict: O, True: O
# 7: Predict: O, True: O
# 14: Predict: O, True: O
# jan: Predict: O, True: O
# qf: Predict: O, True: O
# 21: Predict: O, True: O
# 28: Predict: O, True: O
# jan: Predict: O, True: O
# sf: Predict: O, True: O
# 11feb: Predict: O, True: O
# 4maret: Predict: O, True: O
# final: Predict: O, True: O
# 30: Predict: O, True: O
# mei: Predict: O, True: O
# 2015: Predict: O, True: O
# [*mnctv: Predict: O, True: O
# http://t.co/ptfo5u7er9: Predict: O, True: O
# major: Predict: O, True: O
# caching: Predict: O, True: O
# issue: Predict: O, True: O
# or: Predict: O, True: O
# security: Predict: O, True: O
# breach: Predict: O, True: O
# on: Predict: O, True: O
# #steam: Predict: O, True: B-other
# if: Predict: O, True: O
# you're: Predict: O, True: O
# logged: Predict: O, True: O
# in: Predict: O, True: O
# do: Predict: O, True: O
# not: Predict: O, True: O
# log: Predict: O, True: O
# off: Predict: O, True: O
# and: Predict: O, True: O
# vice: Predict: O, True: O
# versa: Predict: O, True: O
# #goodluckvalve: Predict: O, True: O
# #netsec: Predict: O, True: O
# #merrychristmas: Predict: O, True: O
# @lohudyankees: Predict: O, True: O
# if: Predict: O, True: O
# any: Predict: O, True: O
# 1st: Predict: O, True: O
# baseman: Predict: O, True: O
# in: Predict: O, True: O
# the: Predict: O, True: O
# al: Predict: O, True: B-geo-loc
# so: Predict: O, True: O
# far: Predict: O, True: O
# this: Predict: O, True: O
# season: Predict: O, True: O
# should: Predict: O, True: O
# be: Predict: O, True: O
# starting: Predict: O, True: O
# its: Predict: O, True: O
# either: Predict: O, True: O
# @teixeiramark25: Predict: O, True: O
# or: Predict: O, True: O
# @pujolsfive: Predict: O, True: O
# #believethat: Predict: O, True: O
# curious: Predict: O, True: O
# to: Predict: O, True: O
# see: Predict: O, True: O
# who: Predict: O, True: O
# city: Predict: O, True: B-sportsteam
# buy: Predict: O, True: O
# in: Predict: O, True: O
# january: Predict: O, True: O
# they: Predict: O, True: O
# need: Predict: O, True: O
# a: Predict: O, True: O
# striker: Predict: O, True: O
# desperately: Predict: O, True: O
# in: Predict: O, True: O
# this: Predict: O, True: O
# world: Predict: O, True: O
# nothing: Predict: O, True: O
# can: Predict: O, True: O
# be: Predict: O, True: O
# said: Predict: O, True: O
# to: Predict: O, True: O
# be: Predict: O, True: O
# certain: Predict: O, True: O
# except: Predict: O, True: O
# death: Predict: O, True: O
# taxes: Predict: O, True: O
# and: Predict: O, True: O
# the: Predict: O, True: O
# 1st: Predict: O, True: O
# suspect: Predict: O, True: O
# interviewed: Predict: O, True: O
# in: Predict: O, True: O
# an: Predict: O, True: O
# ep: Predict: O, True: O
# of: Predict: O, True: O
# law: Predict: O, True: B-tvshow
# &amp;: Predict: O, True: I-tvshow
# order: Predict: O, True: I-tvshow
# svu: Predict: O, True: I-tvshow
# didn't: Predict: O, True: O
# do: Predict: O, True: O
# it: Predict: O, True: O
# @heartlessvick: Predict: O, True: O
# lol: Predict: O, True: O
# was: Predict: O, True: O
# george: Predict: O, True: B-person
# with: Predict: O, True: O
# carmen: Predict: O, True: B-person
# today: Predict: O, True: O
# ;d: Predict: O, True: O
# rt: Predict: O, True: O
# @dallasstars: Predict: O, True: O
# ryan: Predict: B-person, True: B-person
# garbutt: Predict: I-person, True: I-person
# and: Predict: O, True: O
# @rous_ant: Predict: O, True: O
# get: Predict: O, True: O
# the: Predict: O, True: O
# assists: Predict: O, True: O
# on: Predict: O, True: O
# fiddler: Predict: O, True: B-person
# 's: Predict: O, True: O
# 8th: Predict: O, True: O
# goal: Predict: O, True: O
# of: Predict: O, True: O
# the: Predict: O, True: O
# season: Predict: O, True: O
# #gostars: Predict: O, True: O
# #nyivsdal: Predict: O, True: O
# http://t.co/nojn2qwj33: Predict: O, True: O
# today: Predict: O, True: O
# 's: Predict: O, True: O
# the: Predict: O, True: O
# day: Predict: O, True: O
# https://t.co/kgqijq29d8: Predict: O, True: O
# for: Predict: O, True: O
# some: Predict: O, True: O
# reason: Predict: O, True: O
# i: Predict: O, True: O
# thought: Predict: O, True: O
# today: Predict: O, True: O
# was: Predict: O, True: O
# monday: Predict: O, True: O
# #wtfmoment: Predict: O, True: O
# i'm: Predict: O, True: O
# glad: Predict: O, True: O
# mattingly: Predict: O, True: B-person
# sat: Predict: O, True: O
# #kershaw: Predict: O, True: B-person
# down: Predict: O, True: O
# before: Predict: O, True: O
# it: Predict: O, True: O
# was: Predict: O, True: O
# too: Predict: O, True: O
# late: Predict: O, True: O
# #dodgersvsmets: Predict: O, True: O
# #dodgersnation: Predict: O, True: O
# #dodgers: Predict: O, True: O
# twas: Predict: O, True: O
# the: Predict: O, True: O
# saturday: Predict: O, True: O
# before: Predict: O, True: O
# christmas: Predict: B-other, True: B-other
# and: Predict: O, True: O
# all: Predict: O, True: O
# the: Predict: O, True: O
# middle: Predict: O, True: O
# aged: Predict: O, True: O
# white: Predict: O, True: O
# women: Predict: O, True: O
# went: Predict: O, True: O
# savage: Predict: O, True: O
# in: Predict: O, True: O
# your: Predict: O, True: O
# local: Predict: O, True: O
# shopping: Predict: O, True: O
# centre: Predict: O, True: O
# rt: Predict: O, True: O
# @whylarryisreal: Predict: O, True: O
# oh: Predict: O, True: O
# no: Predict: O, True: O
# a: Predict: O, True: O
# golden: Predict: O, True: O
# vapor: Predict: O, True: O
# of: Predict: O, True: O
# the: Predict: O, True: O
# sun: Predict: O, True: O
# made: Predict: O, True: O
# human: Predict: O, True: O
# https://t.co/go1d6xg5dy: Predict: O, True: O
# i: Predict: O, True: O
# just: Predict: O, True: O
# took: Predict: O, True: O
# justin: Predict: B-person, True: B-person
# bieber: Predict: I-person, True: I-person
# takes: Predict: O, True: O
# 2: Predict: O, True: O
# months: Predict: O, True: O
# off: Predict: O, True: O
# career: Predict: O, True: O
# to: Predict: O, True: O
# finish: Predict: O, True: O
# school: Predict: O, True: O
# he: Predict: O, True: O
# is: Predict: O, True: O
# a: Predict: O, True: O
# huge: Predict: O, True: O
# and: Predict: O, True: O
# got: Predict: O, True: O
# part: Predict: O, True: O
# 3: Predict: O, True: O
# try: Predict: O, True: O
# it: Predict: O, True: O
# http://tinyurl.com/246946v: Predict: O, True: O
# rt: Predict: O, True: O
# @narrymccuddly: Predict: O, True: O
# these: Predict: O, True: O
# pictures: Predict: O, True: O
# look: Predict: O, True: O
# so: Predict: O, True: O
# weird: Predict: O, True: O
# but: Predict: O, True: O
# when: Predict: O, True: O
# you: Predict: O, True: O
# see: Predict: O, True: O
# the: Predict: O, True: O
# 3rd: Predict: O, True: O
# picture: Predict: O, True: O
# you: Predict: O, True: O
# just: Predict: O, True: O
# understand: Predict: O, True: O
# #proudoflouis: Predict: O, True: O
# http://t.co/yl54qibigv: Predict: O, True: O
# rt: Predict: O, True: O
# @pastorbrady: Predict: O, True: O
# remember: Predict: O, True: O
# every: Predict: O, True: O
# sunday: Predict: O, True: O
# morning: Predict: O, True: O
# gathering: Predict: O, True: O
# at: Predict: O, True: O
# new: Predict: O, True: B-facility
# life: Predict: O, True: I-facility
# can: Predict: O, True: O
# be: Predict: O, True: O
# watched: Predict: O, True: O
# live: Predict: O, True: O
# at: Predict: O, True: O
# 9am: Predict: O, True: O
# and: Predict: O, True: O
# 11am: Predict: O, True: O
# www.nlclive.com: Predict: O, True: O
# rt: Predict: O, True: O
# @johan0394: Predict: O, True: O
# soulja: Predict: B-person, True: B-person
# boy: Predict: I-person, True: I-person
# thedeandreway: Predict: O, True: O
# com: Predict: O, True: O
# the: Predict: O, True: B-other
# deandre: Predict: O, True: I-other
# way: Predict: O, True: I-other
# in: Predict: O, True: O
# stores: Predict: O, True: O
# nov: Predict: O, True: O
# 2: Predict: O, True: O
# 2010: Predict: O, True: O
# http://t.co/eoelod9: Predict: O, True: O
# via: Predict: O, True: O
# @souljaboy: Predict: O, True: O
# looks: Predict: O, True: O
# like: Predict: O, True: O
# we: Predict: O, True: O
# will: Predict: O, True: O
# be: Predict: O, True: O
# living: Predict: O, True: O
# in: Predict: O, True: O
# the: Predict: O, True: O
# studio: Predict: O, True: O
# for: Predict: O, True: O
# the: Predict: O, True: O
# next: Predict: O, True: O
# couple: Predict: O, True: O
# of: Predict: O, True: O
# months: Predict: O, True: O
# @miaturner: Predict: O, True: O
# ooc: Predict: O, True: O
# feeling: Predict: O, True: O
# a: Predict: O, True: O
# little: Predict: O, True: O
# volent: Predict: O, True: O
# today: Predict: O, True: O
# huh: Predict: O, True: O
# @tlrailuk: Predict: O, True: O
# shocking: Predict: O, True: O
# shower: Predict: O, True: O
# of: Predict: O, True: O
# shit: Predict: O, True: O
# you: Predict: O, True: O
# couldn't: Predict: O, True: O
# run: Predict: O, True: O
# a: Predict: O, True: O
# fucking: Predict: O, True: O
# bath: Predict: O, True: O
# wonder: Predict: O, True: O
# if: Predict: O, True: O
# we'll: Predict: O, True: O
# get: Predict: O, True: O
# a: Predict: O, True: O
# rebate: Predict: O, True: O
# in: Predict: O, True: O
# january: Predict: O, True: O
# naaa: Predict: O, True: O
# 10%: Predict: O, True: O
# price: Predict: O, True: O
# hick: Predict: O, True: O
# instead: Predict: O, True: O
# why: Predict: O, True: O
# am: Predict: O, True: O
# i: Predict: O, True: O
# cold: Predict: O, True: O
# in: Predict: O, True: O
# june: Predict: O, True: O
# haha: Predict: O, True: O
# haha: Predict: O, True: O
# 2014: Predict: O, True: O
# has: Predict: O, True: O
# been: Predict: O, True: O
# a: Predict: O, True: O
# great: Predict: O, True: O
# year: Predict: O, True: O
# tomorrow: Predict: O, True: O
# is: Predict: O, True: O
# 2015: Predict: O, True: O
# and: Predict: O, True: O
# that: Predict: O, True: O
# allows: Predict: O, True: O
# me: Predict: O, True: O
# to: Predict: O, True: O
# correct: Predict: O, True: O
# the: Predict: O, True: O
# errors: Predict: O, True: O
# of: Predict: O, True: O
# 2014: Predict: O, True: O
# for: Predict: O, True: O
# a: Predict: O, True: O
# great: Predict: O, True: O
# year: Predict: O, True: O
# happy: Predict: O, True: O
# new: Predict: B-other, True: B-other
# year: Predict: I-other, True: I-other
# everyone: Predict: O, True: O
# well: Predict: O, True: O
# had: Predict: O, True: O
# the: Predict: O, True: O
# weigh: Predict: O, True: O
# in: Predict: O, True: O
# today: Predict: O, True: O
# i've: Predict: O, True: O
# lost: Predict: O, True: O
# a: Predict: O, True: O
# pound: Predict: O, True: O
# i've: Predict: O, True: O
# had: Predict: O, True: O
# no: Predict: O, True: O
# alcohol: Predict: O, True: O
# no: Predict: O, True: O
# puddings: Predict: O, True: O
# no: Predict: O, True: O
# crisps: Predict: O, True: O
# no: Predict: O, True: O
# chocolate: Predict: O, True: O
# &amp;: Predict: O, True: O
# i've: Predict: O, True: O
# only: Predict: O, True: O
# lost: Predict: O, True: O
# a: Predict: O, True: O
# pound: Predict: O, True: O
# 12: Predict: O, True: O
# marketing: Predict: O, True: O
# strategies: Predict: O, True: O
# your: Predict: O, True: O
# business: Predict: O, True: O
# needs: Predict: O, True: O
# for: Predict: O, True: O
# a: Predict: O, True: O
# successful: Predict: O, True: O
# black: Predict: B-other, True: B-other
# friday: Predict: I-other, True: I-other
# forbes: Predict: O, True: O
# via: Predict: O, True: O
# https://t.co/hb5v3mmyxm: Predict: O, True: O
# https://t.co/rce16i0yyt: Predict: O, True: O
# ikaw: Predict: O, True: O
# na: Predict: O, True: O
# na: Predict: O, True: O
# na: Predict: O, True: O
# \\happy: Predict: O, True: O
# 19th: Predict: O, True: O
# monthsary: Predict: O, True: O
# gimme: Predict: O, True: O
# 5//: Predict: O, True: O
# rt: Predict: O, True: O
# @michael_rizzi: Predict: O, True: O
# @patriots: Predict: O, True: O
# will: Predict: O, True: O
# do: Predict: O, True: O
# their: Predict: O, True: O
# job: Predict: O, True: O
# tomorrow: Predict: O, True: O
# #whosgonnawin: Predict: O, True: O
# #vzne: Predict: O, True: O
# rt: Predict: O, True: O
# @wxjerdman: Predict: O, True: O
# after: Predict: O, True: O
# 7+: Predict: O, True: O
# years: Predict: O, True: O
# a: Predict: O, True: O
# #tornado: Predict: O, True: O
# track: Predict: O, True: O
# is: Predict: O, True: O
# still: Predict: O, True: O
# visible: Predict: O, True: O
# in: Predict: O, True: O
# a: Predict: O, True: O
# satellite: Predict: O, True: O
# image: Predict: O, True: O
# saturday: Predict: O, True: O
# via: Predict: O, True: O
# @nwsgreenbay: Predict: O, True: O
# http://t.co/dhjecogyop: Predict: O, True: O
# jsj: Predict: O, True: B-other
# corrects: Predict: O, True: O
# rip: Predict: O, True: O
# currents: Predict: O, True: O
# statement: Predict: O, True: O
# for: Predict: O, True: O
# northwest: Predict: B-geo-loc, True: O
# pr: Predict: B-geo-loc, True: O
# till: Predict: O, True: O
# jul: Predict: O, True: O
# 17: Predict: O, True: O
# 2:00: Predict: O, True: O
# am: Predict: O, True: O
# gmt-4: Predict: O, True: O
# http://t.co/cn7bommm9g: Predict: O, True: O
# #wx: Predict: O, True: O
# http://t.co/chnlh36qsw: Predict: O, True: O
# january: Predict: O, True: O
# 14: Predict: O, True: O
# 2015: Predict: O, True: O
# at: Predict: O, True: O
# 01:06: Predict: O, True: O
# pm: Predict: O, True: O
# @cwwatson: Predict: O, True: O
# one: Predict: O, True: O
# of: Predict: O, True: O
# the: Predict: O, True: O
# complainers: Predict: O, True: O
# is: Predict: O, True: O
# a: Predict: O, True: O
# child: Predict: O, True: O
# minder: Predict: O, True: O
# who: Predict: O, True: O
# brings: Predict: O, True: O
# kids: Predict: O, True: O
# to: Predict: O, True: O
# the: Predict: O, True: O
# school: Predict: O, True: O
# then: Predict: O, True: O
# looks: Predict: O, True: O
# after: Predict: O, True: O
# other: Predict: O, True: O
# kids: Predict: O, True: O
# thro: Predict: O, True: O
# the: Predict: O, True: O
# day: Predict: O, True: O
# beggers: Predict: O, True: O
# belief: Predict: O, True: O
# son: Predict: O, True: O
# popping: Predict: O, True: O
# of: Predict: O, True: O
# to: Predict: O, True: O
# school: Predict: O, True: O
# anybody: Predict: O, True: O
# want: Predict: O, True: O
# a: Predict: O, True: O
# shoutout: Predict: O, True: O
# before: Predict: O, True: O
# i: Predict: O, True: O
# go: Predict: O, True: O
# just: Predict: O, True: O
# ask: Predict: O, True: O
# and: Predict: O, True: O
# ill: Predict: O, True: O
# provide: Predict: O, True: O
# new: Predict: O, True: O
# #ferry: Predict: O, True: O
# schedule: Predict: O, True: O
# starting: Predict: O, True: O
# tomorrow: Predict: O, True: O
# for: Predict: O, True: O
# #langdale: Predict: O, True: B-geo-loc
# #horseshoebay: Predict: O, True: B-geo-loc
# download: Predict: O, True: O
# the: Predict: O, True: O
# simplified: Predict: O, True: O
# version: Predict: O, True: O
# for: Predict: O, True: O
# free: Predict: O, True: O
# http://t.co/eki62ujt0j: Predict: O, True: O
# rt: Predict: O, True: O
# @zodiacfacts: Predict: O, True: O
# #zodiacfacts: Predict: O, True: O
# as: Predict: O, True: O
# an: Predict: O, True: O
# #aries: Predict: O, True: O
# romance: Predict: O, True: O
# is: Predict: O, True: O
# n't: Predict: O, True: O
# about: Predict: O, True: O
# what: Predict: O, True: O
# you: Predict: O, True: O
# 're: Predict: O, True: O
# after: Predict: O, True: O
# it: Predict: O, True: O
# 's: Predict: O, True: O
# about: Predict: O, True: O
# taking: Predict: O, True: O
# chances: Predict: O, True: O
# exploring: Predict: O, True: O
# and: Predict: O, True: O
# keeping: Predict: O, True: O
# an: Predict: O, True: O
# walking: Predict: O, True: O
# into: Predict: O, True: O
# form: Predict: O, True: O
# and: Predict: O, True: O
# not: Predict: O, True: O
# seeing: Predict: O, True: O
# mr: Predict: B-person, True: B-person
# smithson: Predict: I-person, True: I-person
# tomorrow: Predict: O, True: O
# is: Predict: O, True: O
# going: Predict: O, True: O
# to: Predict: O, True: O
# be: Predict: O, True: O
# quite: Predict: O, True: O
# sad: Predict: O, True: O
# i: Predict: O, True: O
# had: Predict: O, True: O
# a: Predict: O, True: O
# substitute: Predict: O, True: O
# today: Predict: O, True: O
# that: Predict: O, True: O
# looked: Predict: O, True: O
# like: Predict: O, True: O
# @thedillon: Predict: O, True: O
# from: Predict: O, True: O
# the: Predict: O, True: O
# side: Predict: O, True: O
# of: Predict: O, True: O
# his: Predict: O, True: O
# face: Predict: O, True: O
# haha: Predict: O, True: O
# rt: Predict: O, True: O
# @kelaish: Predict: O, True: O
# monitor: Predict: O, True: O
# the: Predict: O, True: O
# hashtag: Predict: O, True: O
# at: Predict: O, True: O
# bantayan: Predict: O, True: O
# ang: Predict: O, True: O
# mga: Predict: O, True: O
# magsspam: Predict: O, True: O
# may: Predict: O, True: O
# mga: Predict: O, True: O
# gumagawa: Predict: O, True: O
# ng: Predict: O, True: O
# new: Predict: O, True: O
# accts: Predict: O, True: O
# to: Predict: O, True: O
# spam: Predict: O, True: O
# kasi: Predict: O, True: O
# #psyangpagsinta: Predict: O, True: O
# twenty-four: Predict: O, True: O
# days: Predict: O, True: O
# for: Predict: O, True: O
# costa: Predict: O, True: B-other
# do: Predict: O, True: I-other
# sauipe: Predict: O, True: I-other
# rt: Predict: O, True: O
# @509pilots: Predict: O, True: O
# if: Predict: O, True: O
# you: Predict: O, True: O
# want: Predict: O, True: O
# to: Predict: O, True: O
# dance: Predict: O, True: O
# tomorrow: Predict: O, True: O
# night: Predict: O, True: O
# rays: Predict: O, True: B-facility
# is: Predict: O, True: O
# the: Predict: O, True: O
# spot: Predict: O, True: O
# man: Predict: O, True: O
# i'm: Predict: O, True: O
# telling: Predict: O, True: O
# you: Predict: O, True: O
# ask: Predict: O, True: O
# ya: Predict: O, True: O
# momma: Predict: O, True: O
# she: Predict: O, True: O
# know: Predict: O, True: O
# #topp: Predict: O, True: O
# just: Predict: O, True: O
# about: Predict: O, True: O
# off: Predict: O, True: O
# work: Predict: O, True: O
# going: Predict: O, True: O
# to: Predict: O, True: O
# alderwood: Predict: O, True: B-geo-loc
# again: Predict: O, True: O
# yay: Predict: O, True: O
# hopefully: Predict: O, True: O
# we: Predict: O, True: O
# got: Predict: O, True: O
# cody: Predict: O, True: B-person
# 's: Predict: O, True: O
# ipod: Predict: O, True: B-product
# in: Predict: O, True: O
# the: Predict: O, True: O
# mail: Predict: O, True: O
# today: Predict: O, True: O
# halloween: Predict: B-other, True: B-other
# is: Predict: O, True: O
# tomorrow: Predict: O, True: O
# but: Predict: O, True: O
# that: Predict: O, True: O
# doesn't: Predict: O, True: O
# mean: Predict: O, True: O
# you: Predict: O, True: O
# can't: Predict: O, True: O
# snag: Predict: O, True: O
# a: Predict: O, True: O
# great: Predict: O, True: O
# deal: Predict: O, True: O
# on: Predict: O, True: O
# our: Predict: O, True: O
# halloween: Predict: B-other, True: B-other
# products: Predict: O, True: O
# hurry: Predict: O, True: O
# https://t.co/gr5b758hh8: Predict: O, True: O
# @cheymirria96_: Predict: O, True: O
# this: Predict: O, True: O
# may: Predict: O, True: O
# be: Predict: O, True: O
# helpful: Predict: O, True: O
# as: Predict: O, True: O
# background: Predict: O, True: O
# music: Predict: O, True: O
# for: Predict: O, True: O
# promotional: Predict: O, True: O
# videos: Predict: O, True: O
# or: Predict: O, True: O
# advertisements: Predict: O, True: O
# http://t.co/ghxhbpfxok: Predict: O, True: O
# rt: Predict: O, True: O
# @teamva: Predict: O, True: O
# 81: Predict: O, True: O
# days: Predict: O, True: O
# till: Predict: O, True: O
# last: Predict: O, True: B-other
# sacrifice: Predict: O, True: I-other
# admissions: Predict: O, True: O
# appeals: Predict: O, True: O
# process: Predict: O, True: O
# for: Predict: O, True: O
# athletic: Predict: O, True: O
# recruits: Predict: O, True: O
# may: Predict: O, True: O
# change: Predict: O, True: O
# http://t.co/yhybn9knt7: Predict: O, True: O
# omfresh: Predict: O, True: O
# man: Predict: O, True: O
# he: Predict: O, True: O
# has: Predict: O, True: O
# a: Predict: O, True: O
# body: Predict: O, True: O
# yes: Predict: O, True: O
# i: Predict: O, True: O
# finally: Predict: O, True: O
# saw: Predict: O, True: O
# it: Predict: O, True: O
# today: Predict: O, True: O
# lolz: Predict: O, True: O
# during: Predict: O, True: O
# gym: Predict: O, True: O
# he: Predict: O, True: O
# was: Predict: O, True: O
# lifting: Predict: O, True: O
# up: Predict: O, True: O
# his: Predict: O, True: O
# shirt: Predict: O, True: O
# #teamwonder: Predict: O, True: O
# before: Predict: O, True: O
# we: Predict: O, True: O
# start: Predict: O, True: O
# how: Predict: O, True: O
# old: Predict: O, True: O
# are: Predict: O, True: O
# you: Predict: O, True: O
# her: Predict: O, True: O
# i: Predict: O, True: O
# 'm: Predict: O, True: O
# 15: Predict: O, True: O
# old: Predict: O, True: O
# enough: Predict: O, True: O
# #findthenearestexit: Predict: O, True: O
# a: Predict: O, True: O
# world: Predict: O, True: O
# in: Predict: O, True: O
# which: Predict: O, True: O
# mark: Predict: B-person, True: B-person
# may: Predict: I-person, True: I-person
# and: Predict: O, True: O
# lou: Predict: B-person, True: B-person
# holtz: Predict: I-person, True: I-person
# are: Predict: O, True: O
# allowed: Predict: O, True: O
# to: Predict: O, True: O
# call: Predict: O, True: O
# a: Predict: O, True: O
# bowl: Predict: O, True: O
# game: Predict: O, True: O
# is: Predict: O, True: O
# a: Predict: O, True: O
# world: Predict: O, True: O
# i: Predict: O, True: O
# do: Predict: O, True: O
# not: Predict: O, True: O
# want: Predict: O, True: O
# to: Predict: O, True: O
# live: Predict: O, True: O
# in: Predict: O, True: O
# the: Predict: O, True: O
# farmer: Predict: O, True: O
# stops: Predict: O, True: O
# by: Predict: O, True: O
# the: Predict: O, True: O
# bars: Predict: O, True: O
# of: Predict: O, True: O
# a: Predict: O, True: O
# sunday: Predict: O, True: O
# and: Predict: O, True: O
# looks: Predict: O, True: O
# at: Predict: O, True: O
# the: Predict: O, True: O
# oats: Predict: O, True: O
# and: Predict: O, True: O
# rye: Predict: O, True: O
# rt: Predict: O, True: O
# @vocalunits: Predict: O, True: O
# 11:11: Predict: O, True: O
# may+hoshi: Predict: O, True: O
# rt: Predict: O, True: O
# @falloutboyinfo: Predict: O, True: O
# pete: Predict: B-person, True: B-musicartist
# wentz: Predict: I-person, True: I-musicartist
# interview: Predict: O, True: O
# with: Predict: O, True: O
# zane: Predict: B-person, True: B-musicartist
# lowe: Predict: I-person, True: I-musicartist
# on: Predict: O, True: O
# beats: Predict: O, True: B-company
# 1: Predict: O, True: I-company
# august: Predict: O, True: O
# 2015): Predict: O, True: O
# https://t.co/oga4grvzu3: Predict: O, True: O
# http://t.co/duiiexvvsm: Predict: O, True: O
# @fh14: Predict: O, True: O
# i: Predict: O, True: O
# ironed: Predict: O, True: O
# mine: Predict: O, True: O
# just: Predict: O, True: O
# fine: Predict: O, True: O
# you: Predict: O, True: O
# may: Predict: O, True: O
# want: Predict: O, True: O
# to: Predict: O, True: O
# wash: Predict: O, True: O
# it: Predict: O, True: O
# first: Predict: O, True: O
# though: Predict: O, True: O
# so: Predict: O, True: O
# it: Predict: O, True: O
# gets: Predict: O, True: O
# really: Predict: O, True: O
# soft: Predict: O, True: O
# if: Predict: O, True: O
# you: Predict: O, True: O
# want: Predict: O, True: O
# to: Predict: O, True: O
# be: Predict: O, True: O
# extra: Predict: O, True: O
# safe: Predict: O, True: O
# do: Predict: O, True: O
# on: Predict: O, True: O
# the: Predict: O, True: O
# reverse: Predict: O, True: O
# rt: Predict: O, True: O
# @lohanthony: Predict: O, True: O
# i've: Predict: O, True: O
# come: Predict: O, True: O
# to: Predict: O, True: O
# the: Predict: O, True: O
# realization: Predict: O, True: O
# that: Predict: O, True: O
# i: Predict: O, True: O
# don't: Predict: O, True: O
# hate: Predict: O, True: O
# monday: Predict: O, True: O
# 's: Predict: O, True: O
# i: Predict: O, True: O
# just: Predict: O, True: O
# hate: Predict: O, True: O
# my: Predict: O, True: O
# life: Predict: O, True: O
# flash: Predict: O, True: O
# flood: Predict: O, True: O
# warning: Predict: O, True: O
# issued: Predict: O, True: O
# may: Predict: O, True: O
# 24: Predict: O, True: O
# at: Predict: O, True: O
# 4:00: Predict: O, True: O
# pm: Predict: O, True: O
# mdt: Predict: O, True: O
# until: Predict: O, True: O
# may: Predict: O, True: O
# 25: Predict: O, True: O
# at: Predict: O, True: O
# 12:00: Predict: O, True: O
# am: Predict: O, True: O
# mdt: Predict: O, True: O
# by: Predict: O, True: O
# nws: Predict: O, True: B-other
# http://t.co/lprjyslfjz: Predict: O, True: O
# #wxwy: Predict: O, True: O
# today: Predict: O, True: O
# is: Predict: O, True: O
# my: Predict: O, True: O
# oldest: Predict: O, True: O
# daughters: Predict: O, True: O
# 13th: Predict: O, True: O
# birthday: Predict: O, True: O
# really: Predict: O, True: O
# don't: Predict: O, True: O
# know: Predict: O, True: O
# what: Predict: O, True: O
# to: Predict: O, True: O
# think: Predict: O, True: O
# about: Predict: O, True: O
# her: Predict: O, True: O
# being: Predict: O, True: O
# a: Predict: O, True: O
# teenager: Predict: O, True: O
# except: Predict: O, True: O
# that: Predict: O, True: O
# i: Predict: O, True: O
# am: Predict: O, True: O
# really: Predict: O, True: O
# getting: Predict: O, True: O
# old: Predict: O, True: O
# #oreillyfactor: Predict: O, True: O
# bill: Predict: O, True: B-person
# thinks: Predict: O, True: O
# he: Predict: O, True: O
# has: Predict: O, True: O
# read: Predict: O, True: O
# &amp;: Predict: O, True: O
# understands: Predict: O, True: O
# the: Predict: O, True: O
# 14th: Predict: O, True: B-other
# amendment: Predict: O, True: I-other
# but: Predict: O, True: O
# then: Predict: O, True: O
# he: Predict: O, True: O
# 's: Predict: O, True: O
# a: Predict: O, True: O
# simple: Predict: O, True: O
# man: Predict: O, True: O
# https://t.co/nbrw7bjmlv: Predict: O, True: O
# have: Predict: O, True: O
# you: Predict: O, True: O
# thought: Predict: O, True: O
# about: Predict: O, True: O
# using: Predict: O, True: O
# a: Predict: O, True: O
# business: Predict: O, True: O
# mentor: Predict: O, True: O
# #success: Predict: O, True: O
# #startup: Predict: O, True: O
# #wed: Predict: O, True: O
# https://t.co/o7upk5e3le: Predict: O, True: O
# @torivicotia: Predict: O, True: O
# aaahhh: Predict: O, True: O
# me: Predict: O, True: O
# too: Predict: O, True: O
# its: Predict: O, True: O
# so: Predict: O, True: O
# much: Predict: O, True: O
# better: Predict: O, True: O
# than: Predict: O, True: O
# when: Predict: O, True: O
# you: Predict: O, True: O
# play: Predict: O, True: O
# it: Predict: O, True: O
# yourself: Predict: O, True: O
# haha: Predict: O, True: O
# artful: Predict: O, True: O
# pumpkins: Predict: O, True: O
# ladies: Predict: O, True: O
# long: Predict: O, True: O
# sleeve: Predict: O, True: O
# artful: Predict: O, True: O
# pumpkins: Predict: O, True: O
# ladies: Predict: O, True: O
# long: Predict: O, True: O
# sleeve: Predict: O, True: O
# altered: Predict: O, True: O
# vintage: Predict: O, True: O
# design: Predict: O, True: O
# backgroun: Predict: O, True: O
# http://bit.ly/9rryoi: Predict: O, True: O
# #tshirts: Predict: O, True: O
# lohan: Predict: B-person, True: B-person
# failed: Predict: O, True: O
# a: Predict: O, True: O
# drug: Predict: O, True: O
# test: Predict: O, True: O
# lindsay: Predict: B-person, True: B-person
# lohan: Predict: I-person, True: I-person
# may: Predict: O, True: O
# be: Predict: O, True: O
# in: Predict: O, True: O
# trouble: Predict: O, True: O
# once: Predict: O, True: O
# again: Predict: O, True: O
# the: Predict: O, True: O
# actress: Predict: O, True: O
# who: Predict: O, True: O
# recently: Predict: O, True: O
# completed: Predict: O, True: O
# a: Predict: O, True: O
# stint: Predict: O, True: O
# http://bit.ly/9gefea: Predict: O, True: O
# the: Predict: O, True: O
# end: Predict: O, True: O
# of: Predict: O, True: O
# another: Predict: O, True: O
# week: Predict: O, True: O
# for: Predict: O, True: O
# mts: Predict: O, True: B-company
# rt: Predict: O, True: O
# @tordjman_hannah: Predict: O, True: O
# imaginez: Predict: O, True: O
# mon: Predict: O, True: O
# pere: Predict: O, True: O
# va: Predict: O, True: O
# sur: Predict: O, True: O
# pronote: Predict: O, True: O
# http://t.co/prpg0pixag: Predict: O, True: O
# forget: Predict: O, True: O
# homework: Predict: O, True: O
# kick: Predict: O, True: O
# off: Predict: O, True: O
# your: Predict: O, True: O
# weekend: Predict: O, True: O
# the: Predict: O, True: O
# right: Predict: O, True: O
# way: Predict: O, True: O
# with: Predict: O, True: O
# the: Predict: O, True: B-tvshow
# weekend: Predict: O, True: I-tvshow
# grind: Predict: O, True: I-tvshow
# from: Predict: O, True: O
# 8-10pm: Predict: O, True: O
# tonight: Predict: O, True: O
# “@michaelskolnik: Predict: O, True: O
# more: Predict: O, True: O
# one: Predict: O, True: O
# 19: Predict: O, True: O
# year: Predict: O, True: O
# old: Predict: O, True: O
# woman: Predict: O, True: O
# was: Predict: O, True: O
# shot: Predict: O, True: O
# 7: Predict: O, True: O
# times: Predict: O, True: O
# at: Predict: O, True: O
# the: Predict: O, True: O
# shooting: Predict: O, True: O
# in: Predict: O, True: O
# chicago: Predict: B-geo-loc, True: B-geo-loc
# this: Predict: O, True: O
# morning: Predict: O, True: O
# she: Predict: O, True: O
# is: Predict: O, True: O
# expected: Predict: O, True: O
# to: Predict: O, True: O
# live: Predict: O, True: O
# #prayers”: Predict: O, True: O
# @tos: Predict: O, True: O
# http://t.co/jcraehmehq: Predict: O, True: O
# december: Predict: O, True: O
# 12: Predict: O, True: O
# 2014: Predict: O, True: O
# at: Predict: O, True: O
# 08:31: Predict: O, True: O
# pm: Predict: O, True: O
# is: Predict: O, True: O
# this: Predict: O, True: O
# like: Predict: O, True: O
# no: Predict: O, True: O
# cutting: Predict: O, True: O
# hair: Predict: O, True: O
# december: Predict: O, True: O
# people: Predict: O, True: O
# need: Predict: O, True: O
# to: Predict: O, True: O
# get: Predict: O, True: O
# their: Predict: O, True: O
# hair: Predict: O, True: O
# cut: Predict: O, True: O
# before: Predict: O, True: O
# i: Predict: O, True: O
# use: Predict: O, True: O
# a: Predict: O, True: O
# grass: Predict: O, True: O
# cutter: Predict: O, True: O
# to: Predict: O, True: O
# shave: Predict: O, True: O
# it: Predict: O, True: O
# all: Predict: O, True: O
# off: Predict: O, True: O
# website: Predict: O, True: O
# of: Predict: O, True: O
# the: Predict: O, True: O
# european: Predict: O, True: B-company
# central: Predict: O, True: I-company
# bank: Predict: O, True: I-company
# (#ecb: Predict: O, True: B-company
# has: Predict: O, True: O
# been: Predict: O, True: O
# hacked: Predict: O, True: O
# with: Predict: O, True: O
# personal: Predict: O, True: O
# information: Predict: O, True: O
# stolen: Predict: O, True: O
# #banking: Predict: O, True: O
# #breach: Predict: O, True: O
# http://buff.ly/1lbddnh: Predict: O, True: O
# sunday: Predict: O, True: O
# roundup: Predict: O, True: O
# huffington: Predict: O, True: B-company
# post: Predict: O, True: I-company
# http://t.co/agnwepyp9k: Predict: O, True: O
# #science: Predict: O, True: O
# http://t.co/sc5fgvxeue: Predict: O, True: O
# rt: Predict: O, True: O
# @zeetvtelugu: Predict: O, True: O
# have: Predict: O, True: O
# a: Predict: O, True: O
# super: Predict: O, True: O
# entertaining: Predict: O, True: O
# sunday: Predict: O, True: O
# guys: Predict: O, True: O
# https://t.co/861xqkqjgj: Predict: O, True: O
# rt: Predict: O, True: O
# @commonwhitegiri: Predict: O, True: O
# instagram: Predict: O, True: B-other
# tomorrow: Predict: O, True: O
# http://t.co/oggqinekrl: Predict: O, True: O
# 'rt: Predict: O, True: O
# @amandacarolinne: Predict: O, True: O
# danger: Predict: B-other, True: B-other
# days: Predict: I-other, True: I-other
# the: Predict: I-other, True: I-other
# true: Predict: I-other, True: I-other
# lives: Predict: I-other, True: I-other
# of: Predict: I-other, True: I-other
# the: Predict: I-other, True: I-other
# fabulous: Predict: I-other, True: I-other
# killjoys: Predict: I-other, True: I-other
# getting: Predict: O, True: O
# ready: Predict: O, True: O
# &amp;: Predict: O, True: O
# then: Predict: O, True: O
# out: Predict: O, True: O
# for: Predict: O, True: O
# the: Predict: O, True: O
# nighttttt: Predict: O, True: O
# with: Predict: O, True: O
# my: Predict: O, True: O
# boyfriend: Predict: O, True: O
# tomorrow-sunday: Predict: O, True: O
# &lt;: Predict: O, True: O
# 3: Predict: O, True: O
# 15: Predict: O, True: O
# people: Predict: O, True: O
# wounded: Predict: O, True: O
# after: Predict: O, True: O
# shooting: Predict: O, True: O
# at: Predict: O, True: O
# miami: Predict: B-geo-loc, True: B-geo-loc
# nightclub: Predict: O, True: O
# the: Predict: O, True: O
# victims: Predict: O, True: O
# ranged: Predict: O, True: O
# in: Predict: O, True: O
# age: Predict: O, True: O
# from: Predict: O, True: O
# 11: Predict: O, True: O
# to: Predict: O, True: O
# 25: Predict: O, True: O
# according: Predict: O, True: O
# to: Predict: O, True: O
# a: Predict: O, True: O
# p: Predict: O, True: O
# http://nyti.ms/ywwbda: Predict: O, True: O
# @lizquen_global: Predict: O, True: O
# korek: Predict: O, True: O
# may: Predict: O, True: O
# sound: Predict: O, True: O
# pa: Predict: O, True: O
# yun: Predict: O, True: O
# hahaha: Predict: O, True: O
# what: Predict: O, True: O
# it: Predict: O, True: O
# is: Predict: O, True: O
# twiggas: Predict: O, True: O
# it: Predict: O, True: O
# 's: Predict: O, True: O
# friday: Predict: O, True: O
# in: Predict: O, True: O
# this: Predict: O, True: O
# bissh: Predict: O, True: O
# what: Predict: O, True: O
# 's: Predict: O, True: O
# y'all: Predict: O, True: O
# niggas: Predict: O, True: O
# plans: Predict: O, True: O
# betta: Predict: O, True: O
# be: Predict: O, True: O
# at: Predict: O, True: O
# elements: Predict: O, True: B-facility
# tonight: Predict: O, True: O
# bogo: Predict: O, True: O
# drinks: Predict: O, True: O
# all: Predict: O, True: O
# night: Predict: O, True: O
# nuff: Predict: O, True: O
# said: Predict: O, True: O
# @tastethispeace: Predict: O, True: O
# what: Predict: O, True: O
# time: Predict: O, True: O
# you: Predict: O, True: O
# working: Predict: O, True: O
# tomorrow: Predict: O, True: O
# veeba: Predict: O, True: O
# scenes: Predict: O, True: O
# uploaded: Predict: O, True: O
# by: Predict: O, True: O
# @tonni263: Predict: O, True: O
# 3rd: Predict: O, True: O
# december: Predict: O, True: O
# 2015: Predict: O, True: O
# details: Predict: O, True: O
# of: Predict: O, True: O
# 4.5: Predict: O, True: O
# million: Predict: O, True: O
# individuals: Predict: O, True: O
# exposed: Predict: O, True: O
# in: Predict: O, True: O
# ucla: Predict: B-other, True: B-other
# health: Predict: I-other, True: I-other
# breach: Predict: O, True: O
# http://www.securityweek.com/details-45-million-individuals-exposed-ucla-health-breach?utm_source=feedburner&utm_medium=feed&utm_campaign=feed%3a+securityweek+%28securityweek+rss+feed%29: Predict: O, True: O
# …: Predict: O, True: O
# #infosec: Predict: O, True: O
# big: Predict: O, True: O
# day: Predict: O, True: O
# tomorrow: Predict: O, True: O
# last: Predict: O, True: O
# day: Predict: O, True: O
# of: Predict: O, True: O
# school: Predict: O, True: O
# and: Predict: O, True: O
# there: Predict: O, True: O
# getting: Predict: O, True: O
# swatted: Predict: O, True: O
# let: Predict: O, True: O
# say: Predict: O, True: O
# there: Predict: O, True: O
# a: Predict: O, True: O
# hidden: Predict: O, True: O
# pipe: Predict: O, True: O
# bomb: Predict: O, True: O
# shoutout: Predict: O, True: O
# to: Predict: O, True: O
# the: Predict: O, True: O
# cute: Predict: O, True: O
# boy: Predict: O, True: O
# who: Predict: O, True: O
# just: Predict: O, True: O
# liked: Predict: O, True: O
# my: Predict: O, True: O
# throwback: Predict: O, True: O
# picture: Predict: O, True: O
# on: Predict: O, True: O
# facebook: Predict: B-company, True: B-company
# that: Predict: O, True: O
# i: Predict: O, True: O
# posted: Predict: O, True: O
# on: Predict: O, True: O
# thursday: Predict: O, True: O
# u.s.: Predict: B-other, True: B-other
# hotel: Predict: I-other, True: I-other
# construction: Predict: I-other, True: I-other
# pipeline: Predict: I-other, True: I-other
# for: Predict: O, True: O
# april: Predict: O, True: O
# 2015: Predict: O, True: O
# up: Predict: O, True: O
# 15.2: Predict: O, True: O
# over: Predict: O, True: O
# 2014: Predict: O, True: O
# http://t.co/csmzi6ddta: Predict: O, True: O
# #hoteltrends: Predict: O, True: O
# #smithtravelresearch: Predict: O, True: O
# @zeedoti: Predict: O, True: O
# i: Predict: O, True: O
# might: Predict: O, True: O
# ...
# c'mon: Predict: O, True: O
# just: Predict: O, True: O
# eat: Predict: O, True: O
# one: Predict: O, True: O
# more: Predict: O, True: O
# disgusting: Predict: O, True: O
# thing: Predict: O, True: O
# -the: Predict: O, True: O
# wee: Predict: O, True: O
# hours: Predict: O, True: O
# here: Predict: O, True: O
# 's: Predict: O, True: O
# the: Predict: O, True: O
# inspiring: Predict: O, True: O
# work: Predict: O, True: O
# done: Predict: O, True: O
# at: Predict: O, True: O
# the: Predict: O, True: O
# disability: Predict: O, True: O
# center: Predict: O, True: O
# where: Predict: O, True: O
# the: Predict: O, True: O
# san: Predict: B-geo-loc, True: B-geo-loc
# bernardino: Predict: I-geo-loc, True: I-geo-loc
# shooting: Predict: O, True: O
# took: Predict: O, True: O
# place: Predict: O, True: O
# http://wapo.st/1o4h3sh?tid: Predict: O, True: O
# prayers: Predict: O, True: O
# for: Predict: O, True: O
# all: Predict: O, True: O
# medical: Predict: O, True: O
# resident: Predict: O, True: O
# medical: Predict: O, True: O
# officer: Predict: O, True: O
# pgy3+: Predict: O, True: O
# nsw: Predict: O, True: O
# dec-jan: Predict: O, True: O
# 2015: Predict: O, True: O
# national: Predict: O, True: O
# http://t.co/zs7iwki0nw: Predict: O, True: O
# #engjobs: Predict: O, True: O
# mothers: Predict: O, True: B-other
# day: Predict: O, True: I-other
# greeting: Predict: O, True: O
# cards: Predict: O, True: O
# surrounded: Predict: O, True: O
# by: Predict: O, True: O
# mothers: Predict: B-other, True: B-other
# day: Predict: I-other, True: I-other
# and: Predict: O, True: O
# dreading: Predict: O, True: O
# it: Predict: O, True: O
# http://bit.ly/a7d7tg: Predict: O, True: O
# rt: Predict: O, True: O
# @horny4dabiebs: Predict: O, True: O
# #2: Predict: O, True: O
# justin: Predict: B-musicartist, True: B-musicartist
# heading: Predict: O, True: O
# to: Predict: O, True: O
# a: Predict: O, True: O
# studio: Predict: O, True: O
# in: Predict: O, True: O
# burbank: Predict: B-geo-loc, True: B-geo-loc
# california: Predict: B-geo-loc, True: B-geo-loc
# august: Predict: O, True: O
# 17: Predict: O, True: O
# #mtvhottest: Predict: O, True: O
# justin: Predict: B-musicartist, True: B-musicartist
# bieber: Predict: I-musicartist, True: I-musicartist
# http://t.co/g7bno3uet0: Predict: O, True: O
# rt: Predict: O, True: O
# @bobongquotes: Predict: O, True: O
# live: Predict: O, True: O
# your: Predict: O, True: O
# life: Predict: O, True: O
# while: Predict: O, True: O
# you: Predict: O, True: O
# still: Predict: O, True: O
# can: Predict: O, True: O
# tomorrow: Predict: O, True: O
# is: Predict: O, True: O
# promised: Predict: O, True: O
# to: Predict: O, True: O
# nobody: Predict: O, True: O
# mayday: Predict: B-other, True: O
# parade: Predict: I-other, True: O
# &amp;: Predict: I-other, True: O
# the: Predict: I-other, True: O
# maine: Predict: I-other, True: O
# in: Predict: O, True: O
# like: Predict: O, True: O
# 16: Predict: O, True: O
# days: Predict: O, True: O
# excitedddd: Predict: O, True: O
# all: Predict: O, True: O
# time: Predict: O, True: O
# low: Predict: O, True: O
# next: Predict: O, True: O
# year: Predict: O, True: O
# maybe: Predict: O, True: O
# looks: Predict: O, True: O
# like: Predict: O, True: O
# #king: Predict: O, True: B-other
# county: Predict: O, True: I-other
# #metro: Predict: O, True: O
# may: Predict: O, True: O
# have: Predict: O, True: O
# overestimated: Predict: O, True: O
# the: Predict: O, True: O
# #vanpool: Predict: O, True: O
# demand: Predict: O, True: O
# they: Predict: O, True: O
# just: Predict: O, True: O
# sit: Predict: O, True: O
# in: Predict: O, True: O
# this: Predict: O, True: O
# lot: Predict: O, True: O
# @dorimonson: Predict: O, True: O
# https://t.co/vgsxopo2ap: Predict: O, True: O
# @ipukerkos: Predict: O, True: O
# i: Predict: O, True: O
# cant: Predict: O, True: O
# you'll: Predict: O, True: O
# have: Predict: O, True: O
# to: Predict: O, True: O
# tune: Predict: O, True: O
# into: Predict: O, True: O
# the: Predict: O, True: O
# show: Predict: O, True: O
# this: Predict: O, True: O
# sunday: Predict: O, True: O
# ill: Predict: O, True: O
# give: Predict: O, True: O
# ya: Predict: O, True: O
# a: Predict: O, True: O
# hint: Predict: O, True: O
# he: Predict: O, True: O
# 's: Predict: O, True: O
# a: Predict: O, True: O
# wrestler: Predict: O, True: O
# &amp;: Predict: O, True: O
# has: Predict: O, True: O
# been: Predict: O, True: O
# in: Predict: O, True: O
# the: Predict: O, True: O
# business: Predict: O, True: O
# for: Predict: O, True: O
# 20: Predict: O, True: O
# yrs: Predict: O, True: O
# #sheffield: Predict: O, True: B-geo-loc
# #deal: Predict: O, True: O
# ticket: Predict: O, True: O
# to: Predict: O, True: O
# the: Predict: O, True: O
# first: Predict: O, True: B-other
# utility: Predict: O, True: I-other
# super: Predict: O, True: I-other
# league: Predict: B-other, True: I-other
# grand: Predict: I-other, True: I-other
# final: Predict: I-other, True: I-other
# at: Predict: O, True: O
# old: Predict: B-facility, True: B-facility
# trafford: Predict: I-facility, True: I-facility
# on: Predict: O, True: O
# 10th: Predict: O, True: O
# october: Predict: O, True: O
# http://t.co/nzef8gstxc: Predict: O, True: O
# sendgrid: Predict: B-company, True: B-company
# resets: Predict: O, True: O
# user: Predict: O, True: O
# passwords: Predict: O, True: O
# after: Predict: O, True: O
# breach: Predict: O, True: O
# http://mlz.es/jxidm: Predict: O, True: O
# rt: Predict: O, True: O
# @jakodeleon: Predict: O, True: O
# why: Predict: O, True: O
# not: Predict: O, True: O
# that: Predict: O, True: O
# 's: Predict: O, True: O
# what: Predict: O, True: O
# records: Predict: O, True: O
# are: Predict: O, True: O
# for: Predict: O, True: O
# isn't: Predict: O, True: O
# it: Predict: O, True: O
# hehe: Predict: O, True: O
# #aldub11thweeksary: Predict: O, True: O
# https://t.co/yggalffa1b: Predict: O, True: O
# rt: Predict: O, True: O
# @wisatatiketcom: Predict: O, True: O
# tiket: Predict: O, True: O
# promo: Predict: O, True: O
# ambon: Predict: O, True: B-geo-loc
# jakarta: Predict: O, True: B-geo-loc
# 1-10: Predict: O, True: O
# feb: Predict: O, True: O
# 2015: Predict: O, True: O
# info: Predict: O, True: O
# klik: Predict: O, True: O
# http://t.co/uufjhxv3d7: Predict: O, True: O
# http://t.co/ad4c4galxj: Predict: O, True: O
# ik: Predict: O, True: O
# vind: Predict: O, True: O
# een: Predict: O, True: O
# @youtube-video: Predict: O, True: O
# van: Predict: O, True: O
# @carcrashcomp: Predict: O, True: O
# leuk: Predict: O, True: O
# http://t.co/ako1ntk5g5: Predict: O, True: O
# car: Predict: O, True: O
# crash: Predict: O, True: O
# compilation: Predict: O, True: O
# 497: Predict: O, True: O
# march: Predict: O, True: O
# 2015: Predict: O, True: O
# rt: Predict: O, True: O
# @kincade2000: Predict: O, True: O
# how: Predict: O, True: O
# did: Predict: O, True: O
# i: Predict: O, True: O
# have: Predict: O, True: O
# a: Predict: O, True: O
# cold: Predict: O, True: O
# in: Predict: O, True: O
# april: Predict: O, True: O
# @tattedup_flyty: Predict: O, True: O
# lol: Predict: O, True: O
# hmmm: Predict: O, True: O
# man: Predict: O, True: O
# u: Predict: O, True: O
# kno: Predict: O, True: O
# when: Predict: O, True: O
# u: Predict: O, True: O
# tripped: Predict: O, True: O
# lmao: Predict: O, True: O
# although: Predict: O, True: O
# you: Predict: O, True: O
# may: Predict: O, True: O
# be: Predict: O, True: O
# talking: Predict: O, True: O
# a: Predict: O, True: O
# mile: Predict: O, True: O
# a: Predict: O, True: O
# minute: Predict: O, True: O
# today: Predict: O, True: O
# you: Predict: O, True: O
# still: Predict: O, True: O
# m: Predict: O, True: O
# more: Predict: O, True: O
# for: Predict: O, True: O
# cancer: Predict: O, True: B-other
# http://t.co/5crltesktx: Predict: O, True: O
# @evarley: Predict: O, True: O
# yes: Predict: O, True: O
# thanks: Predict: O, True: O
# we're: Predict: O, True: O
# more: Predict: O, True: O
# traumatised: Predict: O, True: O
# than: Predict: O, True: O
# he: Predict: O, True: O
# is: Predict: O, True: O
# i: Predict: O, True: O
# hate: Predict: O, True: O
# a&amp;e: Predict: O, True: B-other
# &lt;: Predict: O, True: O
# shudders: Predict: O, True: O
# &gt;: Predict: O, True: O
# now: Predict: O, True: O
# it: Predict: O, True: O
# 's: Predict: O, True: O
# time: Predict: O, True: O
# to: Predict: O, True: O
# catch: Predict: O, True: O
# up: Predict: O, True: O
# with: Predict: O, True: O
# the: Predict: O, True: O
# day: Predict: O, True: O
# i: Predict: O, True: O
# stopped: Predict: O, True: O
# listening: Predict: O, True: O
# to: Predict: O, True: O
# this: Predict: O, True: O
# lecture: Predict: O, True: O
# like: Predict: O, True: O
# 20mins: Predict: O, True: O
# ago: Predict: O, True: O
# #sad: Predict: O, True: O
# #newdelhi: Predict: O, True: B-geo-loc
# jan: Predict: O, True: O
# 14: Predict: O, True: O
# 13:30: Predict: O, True: O
# temperature: Predict: O, True: O
# 13c: Predict: O, True: O
# few: Predict: O, True: O
# clouds: Predict: O, True: O
# humidity: Predict: O, True: O
# 80%: Predict: O, True: O
# india: Predict: B-geo-loc, True: B-geo-loc
# http://t.co/jff5nrtfxb: Predict: O, True: O
# rt: Predict: O, True: O
# @bpptkg: Predict: O, True: O
# 11.45: Predict: O, True: O
# via: Predict: O, True: O
# tngm: Predict: B-company, True: O
# penutupan: Predict: I-company, True: O
# jalur: Predict: O, True: O
# pendakian: Predict: O, True: O
# #merapi: Predict: O, True: O
# sejak: Predict: O, True: O
# senin: Predict: O, True: O
# 2: Predict: O, True: O
# nov: Predict: O, True: O
# 2015: Predict: O, True: O
# hingga: Predict: O, True: O
# akhir: Predict: O, True: O
# nov: Predict: O, True: O
# 2015: Predict: O, True: O
# https://t.co/ukijiyypm9: Predict: O, True: O
# fugitive: Predict: O, True: O
# from: Predict: O, True: O
# #montana: Predict: B-geo-loc, True: B-geo-loc
# stabs: Predict: O, True: O
# self: Predict: O, True: O
# during: Predict: O, True: O
# arrest: Predict: O, True: O
# in: Predict: O, True: O
# #mexico: Predict: B-geo-loc, True: B-geo-loc
# nov: Predict: O, True: O
# 3: Predict: O, True: O
# 11:35: Predict: O, True: O
# am: Predict: O, True: O
# et: Predict: O, True: O
# https://t.co/mk6pr2w8a9: Predict: O, True: O
# so: Predict: O, True: O
# i: Predict: O, True: O
# may: Predict: O, True: O
# have: Predict: O, True: O
# taken: Predict: O, True: O
# almost: Predict: O, True: O
# 400: Predict: O, True: O
# pictures: Predict: O, True: O
# at: Predict: O, True: O
# the: Predict: O, True: O
# #dragmatinee: Predict: O, True: O
# tonight: Predict: O, True: O
# i: Predict: O, True: O
# swear: Predict: O, True: O
# when: Predict: O, True: O
# you: Predict: O, True: O
# miss: Predict: O, True: O
# 1: Predict: O, True: O
# day: Predict: O, True: O
# of: Predict: O, True: O
# school: Predict: O, True: O
# feels: Predict: O, True: O
# like: Predict: O, True: O
# you: Predict: O, True: O
# missed: Predict: O, True: O
# a: Predict: O, True: O
# whole: Predict: O, True: O
# year: Predict: O, True: O
# dont: Predict: O, True: O
# even: Predict: O, True: O
# have: Predict: O, True: O
# homwork: Predict: O, True: O
# today: Predict: O, True: O
# suprising: Predict: O, True: O
# @chazzy00: Predict: O, True: O
# what: Predict: O, True: O
# we: Predict: O, True: O
# on: Predict: O, True: O
# tonight: Predict: O, True: O
# friend: Predict: O, True: O
# feature: Predict: O, True: O
# film: Predict: O, True: O
# shooting: Predict: O, True: O
# in: Predict: O, True: O
# nov-dec: Predict: O, True: O
# needs: Predict: O, True: O
# extras: Predict: O, True: O
# $150/day: Predict: O, True: O
# see: Predict: O, True: O
# http://atlanta.craigslist.org/atl/tfr/4702988081.html: Predict: O, True: O
# …: Predict: O, True: O
# for: Predict: O, True: O
# details: Predict: O, True: O
# citizens: Predict: O, True: B-other
# of: Predict: O, True: I-other
# earth: Predict: O, True: I-other
# up: Predict: O, True: O
# on: Predict: O, True: O
# steam: Predict: B-person, True: B-other
# and: Predict: O, True: O
# due: Predict: O, True: O
# the: Predict: O, True: O
# 20th: Predict: O, True: O
# part: Predict: O, True: O
# of: Predict: O, True: O
# me: Predict: O, True: O
# wants: Predict: O, True: O
# to: Predict: O, True: O
# name: Predict: O, True: O
# the: Predict: O, True: O
# vp: Predict: O, True: O
# richard: Predict: B-person, True: B-person
# hawk: Predict: I-person, True: I-person
# http://t.co/rr9xymftlz: Predict: O, True: O
# http://t.co/ftvtdejel6: Predict: O, True: O
# data: Predict: O, True: O
# breach: Predict: O, True: O
# day: Predict: O, True: O
# —: Predict: O, True: O
# patreon: Predict: B-company, True: B-company
# 2.3: Predict: O, True: O
# m): Predict: O, True: O
# t-mobile: Predict: O, True: B-company
# 15m: Predict: O, True: O
# and: Predict: O, True: O
# scottrade: Predict: B-company, True: B-company
# 4.6: Predict: O, True: O
# m: Predict: O, True: O
# —…: Predict: O, True: O
# http://riteio.us/clfzzm: Predict: O, True: O
# digitalproducerpic.twitter.com/wvcpcxkcuy: Predict: O, True: O
# no: Predict: O, True: O
# basic: Predict: O, True: O
# too: Predict: O, True: O
# rt: Predict: O, True: O
# @itsjusabusiness: Predict: O, True: O
# march: Predict: O, True: O
# madnesses: Predict: O, True: O
# and: Predict: O, True: O
# real: Predict: O, True: O
# sisters: Predict: O, True: O
# on: Predict: O, True: O
# repeat: Predict: O, True: O
# mon: Predict: O, True: O
# 15:00: Predict: O, True: O
# temp: Predict: O, True: O
# 1.4: Predict: O, True: O
# c: Predict: O, True: O
# wind: Predict: O, True: O
# ssw: Predict: O, True: O
# 13: Predict: O, True: O
# km/h: Predict: O, True: O
# humidity: Predict: O, True: O
# 71%: Predict: O, True: O
# press: Predict: O, True: O
# 101.6: Predict: O, True: O
# kpa: Predict: O, True: O
# falling: Predict: O, True: O
# rt: Predict: O, True: O
# @artvanfurniture: Predict: O, True: O
# mr: Predict: O, True: B-person
# van: Predict: O, True: I-person
# sure: Predict: O, True: O
# is: Predict: O, True: O
# busy: Predict: O, True: O
# today: Predict: O, True: O
# here: Predict: O, True: O
# he: Predict: O, True: O
# takes: Predict: O, True: O
# time: Predict: O, True: O
# to: Predict: O, True: O
# talk: Predict: O, True: O
# with: Predict: O, True: O
# a: Predict: O, True: O
# crew: Predict: O, True: O
# from: Predict: O, True: O
# @wilxtv: Predict: O, True: O
# http://twitpic.com/2pb3i4: Predict: O, True: O
# when: Predict: O, True: O
# i: Predict: O, True: O
# go: Predict: O, True: O
# to: Predict: O, True: O
# that: Predict: O, True: O
# musical: Predict: O, True: O
# i'm: Predict: O, True: O
# staying: Predict: O, True: O
# near: Predict: O, True: O
# old: Predict: O, True: O
# people: Predict: O, True: O
# so: Predict: O, True: O
# they'll: Predict: O, True: O
# cry: Predict: O, True: O
# w/me: Predict: O, True: O
# like: Predict: O, True: O
# les: Predict: O, True: B-movie
# miserables: Predict: O, True: I-movie
# anyone: Predict: O, True: O
# up: Predict: O, True: O
# for: Predict: O, True: O
# some: Predict: O, True: O
# late: Predict: O, True: O
# night: Predict: O, True: O
# trivia: Predict: O, True: O
# tonight: Predict: O, True: O
# 10pm: Predict: O, True: O
# at: Predict: O, True: O
# summits: Predict: O, True: B-facility
# let: Predict: O, True: O
# me: Predict: O, True: O
# know: Predict: O, True: O
# you: Predict: O, True: O
# gotta: Predict: O, True: O
# let: Predict: O, True: O
# em: Predict: O, True: O
# lick: Predict: O, True: O
# it: Predict: O, True: O
# before: Predict: O, True: O
# they: Predict: O, True: O
# stick: Predict: O, True: O
# it: Predict: O, True: O
# the: Predict: O, True: O
# human: Predict: O, True: O
# problem: Predict: O, True: O
# at: Predict: O, True: O
# the: Predict: O, True: O
# heart: Predict: O, True: O
# of: Predict: O, True: O
# #snapchat’s: Predict: O, True: O
# employee: Predict: O, True: O
# #databreach: Predict: O, True: O
# http://wapo.st/1tpev7c: Predict: O, True: O
# a: Predict: O, True: O
# recent: Predict: O, True: O
# experience: Predict: O, True: O
# may: Predict: O, True: O
# have: Predict: O, True: O
# created: Predict: O, True: O
# unexpected: Predict: O, True: O
# ripples: Predict: O, True: O
# in: Predict: O, True: O
# you: Predict: O, True: O
# more: Predict: O, True: O
# for: Predict: O, True: O
# gemini: Predict: B-other, True: B-other
# http://t.co/lm2nyfv2va: Predict: O, True: O
# @chrisdimino: Predict: O, True: O
# i: Predict: O, True: O
# believe: Predict: O, True: O
# that: Predict: O, True: O
# is: Predict: O, True: O
# the: Predict: O, True: O
# 3rd: Predict: O, True: O
# 26: Predict: O, True: O
# yard: Predict: O, True: O
# play: Predict: O, True: O
# by: Predict: O, True: O
# ohio: Predict: B-sportsteam, True: B-sportsteam
# state: Predict: I-sportsteam, True: I-sportsteam
# starting: Predict: O, True: O
# from: Predict: O, True: O
# their: Predict: O, True: O
# end: Predict: O, True: O
# zone: Predict: O, True: O
# this: Predict: O, True: O
# half: Predict: O, True: O
